# %% [markdown]
# # Colab Setup

# %%
from google.colab import drive

drive.mount("/content/drive")

import os

GDRIVE_PATH = "/content/drive/MyDrive/github"
REPO_NAME = "swiftcounter-cv"
REPO_URL = "https://github.com/aravindh28/swiftcounter-cv.git"
CLONE_PATH = os.path.join(GDRIVE_PATH, REPO_NAME)
BRANCH = "dev/manav"

print(f"Creating folder: {GDRIVE_PATH}")
os.makedirs(GDRIVE_PATH, exist_ok=True)

if not os.path.exists(CLONE_PATH):
    print("🔄 Cloning repository...")
    # !git clone {REPO_URL} {CLONE_PATH}; git checkout {BRANCH}
else:
    print("📥 Pulling latest changes...")
    # %cd {CLONE_PATH}
    # !git checkout {BRANCH}; git pull origin $(git rev-parse --abbrev-ref HEAD)
