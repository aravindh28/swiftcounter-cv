# %% [markdown]
# # Colab Setup

# %%
# -*- coding: utf-8 -*-
"""
Cleaned Bird Classification Pipeline
Optimized for multiple bird counting with simplified, efficient code
"""

# ============================================================================
# COLAB SETUP
# ============================================================================

# Install required packages
# !pip install yt-dlp ultralytics opencv-python tqdm numpy

# Mount Google Drive
from google.colab import drive
drive.mount("/content/drive")

# ============================================================================
# IMPORTS AND SETUP
# ============================================================================

import numpy as np
import cv2
import torch
import json
import math
from tqdm import tqdm
from ultralytics import YOLO, SAM
from datetime import datetime
import os
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.11/dist-packages (2025.5.22)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.152)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Config

# %%
# ============================================================================
# CONFIGURATION
# ============================================================================

# Set your path - UPDATE THIS to match your Google Drive structure
PATH = "drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments"

# Check if path exists and create data directory if needed
# !ls {PATH}
# !mkdir -p {PATH}/data

print(f"✅ Working directory: {PATH}")
print(f"📁 Data directory: {PATH}/data")

# IMPORTANT: Ensure cookies.txt is in the data directory for YouTube downloads
print("📌 IMPORTANT: Make sure cookies.txt is in the data directory for video downloads!")
print(f"   Expected location: {PATH}/data/cookies.txt")

# ROI polygon (rectangle around chimney)
roi_polygon = np.array([
    [580, 550],  # top-left
    [780, 550],  # top-right
    [780, 720],  # bottom-right
    [580, 720],  # bottom-left
], dtype=int)

# Save ROI for use by tracker
roi_save_path = f"{PATH}/data/roi_polygon.npy"
np.save(roi_save_path, roi_polygon)
print(f"✅ ROI coordinates: {roi_polygon.tolist()}")
print(f"✅ ROI saved to: {roi_save_path}")

# Test segments configuration
segments_to_test = [
    {"start": "0:05", "end": "0:16", "expected_count": 47, "name": "original_working"}
]

VIDEO_URL = "https://www.youtube.com/watch?v=mkquDCpPD9c"
# Out:
# colab-setup-manav.ipynb      data		   video_download.py
# colanb-setup-aravindh.ipynb  pipeline-manav.ipynb
# ✅ Working directory: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments
# 📁 Data directory: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments/data
# 📌 IMPORTANT: Make sure cookies.txt is in the data directory for video downloads!
#    Expected location: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments/data/cookies.txt
# ✅ ROI coordinates: [[580, 550], [780, 550], [780, 720], [580, 720]]
# ✅ ROI saved to: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments/data/roi_polygon.npy

# %% [markdown]
# Helper functions

# %%
# ============================================================================
# HELPER FUNCTIONS (Including Integrated Video Download)
# ============================================================================

import subprocess
import yt_dlp

def time_str_to_seconds(time_str):
    """Convert MM:SS format to seconds for yt-dlp"""
    if ':' in time_str:
        parts = time_str.split(':')
        if len(parts) == 2:
            minutes, seconds = parts
            return int(minutes) * 60 + int(seconds)
        elif len(parts) == 3:
            hours, minutes, seconds = parts
            return int(hours) * 3600 + int(minutes) * 60 + int(seconds)
    return int(time_str)

def time_str_to_filename(time_str):
    """Convert MM:SS to filename-safe format"""
    return time_str.replace(':', '-')

def precise_trim(input_path, output_path, start, end):
    """Precise video trimming using ffmpeg for frame accuracy"""
    duration = end - start
    print(f"✂️  Trimming {input_path} from {start}s to {end}s into {output_path}")
    cmd = [
        "ffmpeg",
        "-y",
        "-i", input_path,
        "-ss", str(start),
        "-t", str(duration),
        "-c:v", "libx264",
        "-an",        # no audio
        output_path
    ]
    result = subprocess.run(cmd, capture_output=True)
    if result.returncode == 0:
        print("✅ Precise trim complete!")
        return True
    else:
        print(f"❌ ffmpeg trimming failed:\n{result.stderr.decode()}")
        return False

def download_video(url, filename, start=None, end=None):
    """Integrated video download using yt-dlp with optional precise trimming"""
    # Download to a temporary file if segmenting
    temp_filename = filename
    if start is not None and end is not None:
        temp_filename = filename.replace('.mp4', '_raw.mp4')

    if os.path.exists(filename) and os.path.getsize(filename) > 0:
        print(f"✅ File '{filename}' already exists and is non-empty. Skipping download.")
        return True

    ydl_opts = {
        "outtmpl": temp_filename,
        "format": "bestvideo[height<=720][ext=mp4]/bestvideo[height<=720]/best",
        "merge_output_format": "mp4",
        "quiet": False,
        "noplaylist": True,
    }

    # Use cookies if found in data/
    cookies_path = os.path.join(f"{PATH}/data", "cookies.txt")
    if os.path.exists(cookies_path):
        print(f"🔐 Using cookies from '{cookies_path}'")
        ydl_opts["cookies"] = cookies_path

    print(f"📥 Downloading video from {url} to {temp_filename}")
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
            print("✅ Download complete!")
    except Exception as e:
        print(f"❌ Download failed:\n{e}")
        return False

    # If segment requested, trim with ffmpeg for frame accuracy
    if start is not None and end is not None:
        success = precise_trim(temp_filename, filename, start, end)
        if temp_filename != filename and os.path.exists(temp_filename):
            os.remove(temp_filename)  # Clean up temp file
        return success

    return True

def download_video_segment_unique(video_url, start_time, end_time, segment_name):
    """Download video segment with caching - only downloads if file doesn't exist"""
    start_sec = time_str_to_seconds(start_time)
    end_sec = time_str_to_seconds(end_time)

    # Create unique filename
    start_filename = time_str_to_filename(start_time)
    end_filename = time_str_to_filename(end_time)
    unique_filename = f"downloaded_video_{start_filename}_to_{end_filename}.mp4"
    unique_path = f"{PATH}/data/{unique_filename}"

    # CHECK IF FILE ALREADY EXISTS (CACHING FIX)
    if os.path.exists(unique_path) and os.path.getsize(unique_path) > 0:
        print(f"✅ Using existing file: {unique_filename}")
        return unique_path, unique_filename

    print(f"📥 Downloading segment '{segment_name}': {start_time} to {end_time}")
    print(f"   Time range: {start_sec}s to {end_sec}s")
    print(f"   Saving as: {unique_filename}")

    # Ensure the data directory exists
    os.makedirs(f"{PATH}/data", exist_ok=True)

    # Use integrated download function instead of external script
    success = download_video(video_url, unique_path, start_sec, end_sec)

    if success and os.path.exists(unique_path):
        print(f"✅ Video saved as: {unique_filename}")
        return unique_path, unique_filename
    else:
        print(f"❌ Failed to download video segment")
        return None, None

# %% [markdown]
# Bird tracker class

# %%
# ============================================================================
# SIMPLIFIED BIRD TRACKER CLASS
# ============================================================================

class AggressiveBirdTracker:
    """Simplified bird tracker focused on multiple bird detection"""

    def __init__(self, roi_polygon,
                 # Core parameters only
                 yolo_confidence=0.08,
                 roi_entry_threshold=0.1,
                 tracking_zone_radius=150,
                 min_track_length=3,
                 max_distance_for_matching=80,

                 # Recovery system
                 track_recovery_enabled=True,
                 max_frames_to_recover=5,
                 recovery_distance_threshold=120,
                 recovery_confidence_threshold=0.6,

                 # Debug
                 debug_mode=True):

        # Core setup
        self.roi_polygon = roi_polygon
        self.bird_tracks = {}
        self.next_track_id = 1
        self.birds_entered_roi = set()
        self.frame_count = 0

        # Parameters
        self.yolo_confidence = yolo_confidence
        self.roi_entry_threshold = roi_entry_threshold
        self.tracking_zone_radius = tracking_zone_radius
        self.min_track_length = min_track_length
        self.max_distance_for_matching = max_distance_for_matching

        # Recovery system
        self.track_recovery_enabled = track_recovery_enabled
        self.max_frames_to_recover = max_frames_to_recover
        self.recovery_distance_threshold = recovery_distance_threshold
        self.recovery_confidence_threshold = recovery_confidence_threshold

        self.debug_mode = debug_mode

        # ROI bounds calculation
        self.roi_min_x, self.roi_min_y = np.min(self.roi_polygon, axis=0)
        self.roi_max_x, self.roi_max_y = np.max(self.roi_polygon, axis=0)
        self.roi_center = ((self.roi_min_x + self.roi_max_x) // 2,
                          (self.roi_min_y + self.roi_max_y) // 2)

        # Recovery system
        self.recently_lost_tracks = {}
        self.recovery_stats = {'recoveries_attempted': 0, 'recoveries_successful': 0}

        print(f"🎯 Bird Tracker initialized for multiple bird detection:")
        print(f"   YOLO confidence: {self.yolo_confidence}")
        print(f"   ROI rectangle: ({self.roi_min_x},{self.roi_min_y}) to ({self.roi_max_x},{self.roi_max_y})")
        print(f"   Tracking zone: {self.tracking_zone_radius}px radius")
        print(f"   Track Recovery: {'ENABLED' if self.track_recovery_enabled else 'DISABLED'}")

    def get_mask_centroid(self, mask):
        """Calculate centroid of segmentation mask"""
        y_coords, x_coords = np.where(mask > 0)
        if len(x_coords) == 0:
            return None
        return (int(np.mean(x_coords)), int(np.mean(y_coords)))

    def calculate_distance(self, point1, point2):
        """Calculate Euclidean distance between two points"""
        return math.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

    def is_point_in_roi_rectangle(self, point):
        """Check if point is inside ROI rectangle"""
        x, y = point
        return (self.roi_min_x <= x <= self.roi_max_x and
                self.roi_min_y <= y <= self.roi_max_y)

    def is_in_tracking_zone(self, centroid):
        """Check if bird is within tracking zone"""
        distance_to_center = self.calculate_distance(centroid, self.roi_center)
        return distance_to_center <= self.tracking_zone_radius

    def simple_roi_detection(self, bird_mask):
        """Simplified ROI detection for multiple birds"""
        try:
            y_coords, x_coords = np.where(bird_mask > 0)
            if len(x_coords) == 0:
                return False, 0.0

            # Check if any pixels overlap with ROI rectangle
            roi_pixels = 0
            for i in range(0, len(x_coords), 2):  # Sample every 2nd pixel for speed
                x, y = x_coords[i], y_coords[i]
                if self.is_point_in_roi_rectangle((x, y)):
                    roi_pixels += 1

            if roi_pixels > 0:
                return True, 1.0

            # Check centroid with small buffer
            centroid_x = int(np.mean(x_coords))
            centroid_y = int(np.mean(y_coords))

            buffer = 5
            for dx in range(-buffer, buffer + 1):
                for dy in range(-buffer, buffer + 1):
                    test_point = (centroid_x + dx, centroid_y + dy)
                    if self.is_point_in_roi_rectangle(test_point):
                        return True, 0.8

            return False, 0.0

        except Exception as e:
            if self.debug_mode:
                print(f"ROI detection error: {e}")
            return False, 0.0

    def get_sam2_mask_id(self, mask, mask_index=None):
        """Generate stable mask ID"""
        if mask_index is not None:
            return f"sam2_mask_{mask_index}"
        return None

    def predict_next_position(self, track_data):
        """Simple position prediction for recovery"""
        centroid_history = track_data.get('centroid_history', [])

        if len(centroid_history) < 2:
            return centroid_history[-1] if centroid_history else None

        # Linear prediction from last 2 positions
        last_pos = centroid_history[-1]
        prev_pos = centroid_history[-2]

        vx = last_pos[0] - prev_pos[0]
        vy = last_pos[1] - prev_pos[1]

        predicted_pos = (int(last_pos[0] + vx), int(last_pos[1] + vy))
        return predicted_pos

    def attempt_track_recovery(self, unmatched_detections):
        """Track recovery system for handling multiple birds"""
        if not self.track_recovery_enabled or not self.recently_lost_tracks:
            return unmatched_detections, []

        recovered_tracks = []
        still_unmatched = []

        for detection in unmatched_detections:
            detection_centroid = detection['centroid']
            best_recovery_score = 0.0
            best_recovery_track_id = None

            for lost_track_id, lost_info in self.recently_lost_tracks.items():
                frames_since_lost = self.frame_count - lost_info['lost_frame']

                if frames_since_lost > self.max_frames_to_recover:
                    continue

                predicted_pos = self.predict_next_position(lost_info['track_data'])
                if predicted_pos:
                    distance = self.calculate_distance(detection_centroid, predicted_pos)

                    if distance <= self.recovery_distance_threshold:
                        score = 1.0 - (distance / self.recovery_distance_threshold)
                        score *= (1.0 - (frames_since_lost / self.max_frames_to_recover))

                        if score > best_recovery_score and score >= self.recovery_confidence_threshold:
                            best_recovery_score = score
                            best_recovery_track_id = lost_track_id

            if best_recovery_track_id is not None:
                # Recover the track
                lost_info = self.recently_lost_tracks[best_recovery_track_id]
                recovered_track_data = lost_info['track_data'].copy()

                recovered_track_data['centroid_history'].append(detection_centroid)
                recovered_track_data['last_seen'] = self.frame_count
                recovered_track_data['sam2_mask_id'] = detection.get('sam2_mask_id')

                self.bird_tracks[best_recovery_track_id] = recovered_track_data
                del self.recently_lost_tracks[best_recovery_track_id]

                self.recovery_stats['recoveries_attempted'] += 1
                self.recovery_stats['recoveries_successful'] += 1

                recovered_tracks.append({
                    'track_id': best_recovery_track_id,
                    'detection': detection
                })

                if self.debug_mode:
                    gap_frames = self.frame_count - lost_info['lost_frame']
                    print(f"🔄 RECOVERED Track #{best_recovery_track_id} after {gap_frames} frames")
            else:
                still_unmatched.append(detection)

        return still_unmatched, recovered_tracks

    def update_recently_lost_tracks(self):
        """Update recently lost tracks buffer"""
        tracks_to_move = []
        for track_id, track_data in self.bird_tracks.items():
            frames_since_seen = self.frame_count - track_data['last_seen']
            if frames_since_seen >= 1:
                tracks_to_move.append(track_id)

        for track_id in tracks_to_move:
            if track_id not in self.recently_lost_tracks:
                self.recently_lost_tracks[track_id] = {
                    'track_data': self.bird_tracks[track_id].copy(),
                    'lost_frame': self.bird_tracks[track_id]['last_seen'] + 1
                }
            del self.bird_tracks[track_id]

        # Clean up old tracks
        old_tracks = []
        for track_id, lost_info in self.recently_lost_tracks.items():
            frames_since_lost = self.frame_count - lost_info['lost_frame']
            if frames_since_lost > self.max_frames_to_recover:
                old_tracks.append(track_id)

        for track_id in old_tracks:
            del self.recently_lost_tracks[track_id]

    def update_tracks(self, bird_detections):
        """Main tracking update for multiple birds"""
        self.frame_count += 1
        self.update_recently_lost_tracks()

        # Filter detections to tracking zone
        zone_detections = []
        birds_in_roi_this_frame = 0

        for i, detection in enumerate(bird_detections):
            mask = detection['mask']
            confidence = float(detection['confidence'])
            sam2_mask_id = detection.get('sam2_mask_id', self.get_sam2_mask_id(mask, mask_index=i))
            centroid = self.get_mask_centroid(mask)

            if centroid and self.is_in_tracking_zone(centroid):
                in_roi, roi_confidence = self.simple_roi_detection(mask)
                if in_roi:
                    birds_in_roi_this_frame += 1

                zone_detections.append({
                    'centroid': centroid,
                    'mask': mask,
                    'confidence': confidence,
                    'roi_confidence': roi_confidence,
                    'in_roi': in_roi,
                    'sam2_mask_id': sam2_mask_id
                })

        # Track matching
        matched_tracks = set()
        unmatched_detections = []

        for curr_data in zone_detections:
            curr_centroid = curr_data['centroid']
            sam2_mask_id = curr_data['sam2_mask_id']
            best_match_id = None
            best_score = 0.0

            # Try SAM2 ID matching first
            for track_id, track_data in self.bird_tracks.items():
                if track_id in matched_tracks:
                    continue

                if (track_data.get('sam2_mask_id') == sam2_mask_id and
                    sam2_mask_id is not None):
                    best_match_id = track_id
                    best_score = 1.0
                    break

            # Distance matching as fallback
            if best_match_id is None:
                for track_id, track_data in self.bird_tracks.items():
                    if track_id in matched_tracks:
                        continue

                    last_centroid = track_data['centroid_history'][-1]
                    distance = self.calculate_distance(curr_centroid, last_centroid)

                    if distance <= self.max_distance_for_matching:
                        score = 1.0 - (distance / self.max_distance_for_matching)
                        if score > best_score:
                            best_score = score
                            best_match_id = track_id

            if best_match_id is not None and best_score > 0.3:
                # Update existing track
                matched_tracks.add(best_match_id)
                track_data = self.bird_tracks[best_match_id]
                track_data['centroid_history'].append(curr_centroid)
                track_data['last_seen'] = self.frame_count
                track_data['sam2_mask_id'] = sam2_mask_id

                # Check for ROI entry
                if not track_data['entered_roi']:
                    roi_entered = (curr_data['in_roi'] and
                                  curr_data['roi_confidence'] >= self.roi_entry_threshold and
                                  len(track_data['centroid_history']) >= self.min_track_length)

                    if roi_entered:
                        track_data['entered_roi'] = True
                        track_data['entry_location'] = curr_centroid
                        track_data['entry_frame'] = self.frame_count
                        self.birds_entered_roi.add(best_match_id)

                        print(f"🐦 Bird #{best_match_id} entered ROI at frame {self.frame_count}")
                        print(f"   Entry location: {curr_centroid}")
                        print(f"   Track length: {len(track_data['centroid_history'])} frames")
            else:
                unmatched_detections.append(curr_data)

        # Track recovery
        still_unmatched, recovered_tracks = self.attempt_track_recovery(unmatched_detections)

        # Process recovered tracks for ROI entry
        for recovery_info in recovered_tracks:
            track_id = recovery_info['track_id']
            detection = recovery_info['detection']
            track_data = self.bird_tracks[track_id]

            if not track_data['entered_roi']:
                roi_entered = (detection['in_roi'] and
                              detection['roi_confidence'] >= self.roi_entry_threshold and
                              len(track_data['centroid_history']) >= self.min_track_length)

                if roi_entered:
                    track_data['entered_roi'] = True
                    track_data['entry_location'] = detection['centroid']
                    track_data['entry_frame'] = self.frame_count
                    self.birds_entered_roi.add(track_id)
                    print(f"🐦 RECOVERED Bird #{track_id} entered ROI at frame {self.frame_count}")

        # Create new tracks
        for new_data in still_unmatched:
            track_id = self.next_track_id

            self.bird_tracks[track_id] = {
                'centroid_history': [new_data['centroid']],
                'entered_roi': False,
                'last_seen': self.frame_count,
                'sam2_mask_id': new_data['sam2_mask_id']
            }

            # Immediate ROI entry for new tracks (if min_track_length is 1)
            if (new_data['in_roi'] and
                new_data['roi_confidence'] >= self.roi_entry_threshold and
                self.min_track_length <= 1):

                self.bird_tracks[track_id]['entered_roi'] = True
                self.bird_tracks[track_id]['entry_location'] = new_data['centroid']
                self.bird_tracks[track_id]['entry_frame'] = self.frame_count
                self.birds_entered_roi.add(track_id)
                print(f"🐦 NEW Bird #{track_id} entered ROI at frame {self.frame_count}")

            self.next_track_id += 1

        # Debug output for multiple birds
        if birds_in_roi_this_frame > 0 or len(zone_detections) > 0:
            active_tracks = len(self.bird_tracks)
            lost_tracks = len(self.recently_lost_tracks)
            counted_birds = len(self.birds_entered_roi)

            print(f"🔍 Frame {self.frame_count}: {len(zone_detections)} detections, "
                  f"{birds_in_roi_this_frame} in ROI, {active_tracks} active, "
                  f"{lost_tracks} lost, {counted_birds} counted")

    def process_end_of_video(self):
        """End-of-video processing for remaining tracks"""
        print(f"\n🏁 End-of-video processing - checking {len(self.bird_tracks)} tracks...")

        final_counts_added = 0
        for track_id, track_data in self.bird_tracks.items():
            if not track_data['entered_roi']:
                # Check recent frames for ROI presence
                recent_frames = min(3, len(track_data['centroid_history']))
                roi_hits = 0

                for i in range(-recent_frames, 0):
                    if abs(i) <= len(track_data['centroid_history']):
                        centroid_idx = len(track_data['centroid_history']) + i
                        if centroid_idx >= 0:
                            centroid = track_data['centroid_history'][centroid_idx]
                            if self.is_point_in_roi_rectangle(centroid):
                                roi_hits += 1

                if roi_hits >= 1:  # Any ROI hit in recent frames
                    track_data['entered_roi'] = True
                    track_data['entry_location'] = track_data['centroid_history'][-1]
                    track_data['entry_frame'] = self.frame_count
                    self.birds_entered_roi.add(track_id)
                    final_counts_added += 1
                    print(f"🐦 FINAL: Bird #{track_id} counted (was in ROI {roi_hits}/{recent_frames} recent frames)")

        if final_counts_added > 0:
            print(f"✅ Added {final_counts_added} birds from end-of-video processing")

        return final_counts_added

    def get_count(self):
        """Get total count of birds that entered ROI"""
        return len(self.birds_entered_roi)

    def get_tracking_info(self):
        """Get tracking information"""
        return {
            'total_birds_entered': len(self.birds_entered_roi),
            'active_tracks': len(self.bird_tracks),
            'recently_lost_tracks': len(self.recently_lost_tracks),
            'confirmed_entries': list(self.birds_entered_roi),
            'recovery_stats': self.recovery_stats.copy()
        }

# %% [markdown]
# Detection and processing

# %%
# ============================================================================
# DETECTION AND PROCESSING FUNCTIONS
# ============================================================================

def conservative_yolo_detection(model, frame, device, confidence=0.08, iou=0.4, max_det=100):
    """YOLO detection with optimized parameters"""
    results = model.predict(
        source=frame,
        device=device,
        conf=confidence,
        iou=iou,
        max_det=max_det,
        verbose=False
    )[0]
    return results

def aggressive_bird_counting_pipeline(video_path, output_suffix=""):
    """Main processing pipeline optimized for multiple birds"""

    # Generate output names
    base_name = os.path.splitext(os.path.basename(video_path))[0]
    output_video_path = f"{PATH}/data/sam2_output_{base_name}{output_suffix}.mp4"
    output_json_path = f"{PATH}/data/sam2_results_{base_name}{output_suffix}.json"

    # Load ROI from saved file
    roi_path = f"{PATH}/data/roi_polygon.npy"
    roi_polygon = np.load(roi_path)

    # Initialize tracker
    bird_tracker = AggressiveBirdTracker(roi_polygon)

    # Load models
    if not os.path.exists("yolo11x.pt"):
        print("📥 Downloading YOLO model...")
        import subprocess
        subprocess.run(["wget", "https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt"],
                      check=True, capture_output=True)

    yolo = YOLO("yolo11x.pt")
    sam = SAM("sam2_b.pt")
    device = 0 if torch.cuda.is_available() else "cpu"

    # Video setup
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    print(f"🎯 PROCESSING FOR MULTIPLE BIRDS")
    print(f"🎯 Video info: {frame_count} total frames at {fps:.1f} fps")

    # Main processing loop
    all_results = []
    frame_idx = 0

    with tqdm(total=frame_count, desc="Processing multiple birds") as pbar:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            try:
                vis_frame = frame.copy()

                # Draw ROI
                cv2.polylines(vis_frame, [roi_polygon], isClosed=True, color=(0, 255, 255), thickness=2)
                cv2.putText(vis_frame, "CHIMNEY ROI", (roi_polygon[0][0], roi_polygon[0][1] - 10),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

                # YOLO detection
                yolo_result = conservative_yolo_detection(yolo, frame, device)

                # Filter for birds
                bird_boxes = []
                bird_confidences = []

                if yolo_result and yolo_result.boxes is not None:
                    for box in yolo_result.boxes:
                        try:
                            cls_id = int(box.cls)
                            confidence = float(box.conf.item()) if hasattr(box.conf, 'item') else float(box.conf)
                            class_name = yolo.names[cls_id]

                            if class_name == 'bird' and confidence >= 0.05:
                                bird_boxes.append(box.xyxy[0].cpu().numpy().tolist())
                                bird_confidences.append(confidence)
                        except:
                            continue

                bird_detections = []

                if bird_boxes:
                    try:
                        # SAM segmentation
                        sam_result = sam.predict(source=frame, bboxes=bird_boxes, device=device, verbose=False)[0]

                        if sam_result.masks is not None:
                            masks = sam_result.masks.data.cpu().numpy()

                            for i, mask in enumerate(masks):
                                try:
                                    confidence = bird_confidences[i]
                                    sam2_mask_id = bird_tracker.get_sam2_mask_id(mask, mask_index=i)

                                    bird_detections.append({
                                        'mask': mask,
                                        'confidence': confidence,
                                        'bbox': bird_boxes[i],
                                        'frame_idx': frame_idx,
                                        'sam2_mask_id': sam2_mask_id
                                    })

                                    # Visualization
                                    color = [int(c) for c in np.random.randint(80, 220, 3)]
                                    mask_img = (mask * 255).astype(np.uint8)
                                    contours, _ = cv2.findContours(mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                                    if contours:
                                        cv2.drawContours(vis_frame, contours, -1, color, 2)
                                        centroid = bird_tracker.get_mask_centroid(mask)
                                        if centroid and 0 <= centroid[0] < width and 0 <= centroid[1] < height:
                                            cv2.putText(vis_frame, f"{confidence:.2f}",
                                                       (centroid[0] + 5, centroid[1] - 5),
                                                       cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1)
                                except:
                                    continue
                    except Exception as e:
                        print(f"SAM error at frame {frame_idx}: {e}")

                # Update tracking
                bird_tracker.update_tracks(bird_detections)

                # Get current count
                tracking_info = bird_tracker.get_tracking_info()
                current_count = tracking_info['total_birds_entered']

                # Text overlay
                overlay = vis_frame.copy()
                cv2.rectangle(overlay, (5, 5), (400, 120), (0, 0, 0), -1)
                vis_frame = cv2.addWeighted(vis_frame, 0.8, overlay, 0.2, 0)

                cv2.putText(vis_frame, f"BIRDS COUNTED: {current_count}",
                           (10, 35), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 2)

                cv2.putText(vis_frame, f"Frame: {frame_idx:03d}/{frame_count} | Detected: {len(bird_detections):02d}",
                           (10, 65), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

                cv2.putText(vis_frame, f"Active: {tracking_info['active_tracks']:02d} | Lost: {tracking_info['recently_lost_tracks']:02d}",
                           (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

                # Show counted birds as green dots
                for track_id, track_data in bird_tracker.bird_tracks.items():
                    if track_data['entered_roi'] and 'entry_location' in track_data:
                        entry_point = track_data['entry_location']
                        if (entry_point and len(entry_point) == 2 and
                            0 <= entry_point[0] < width and 0 <= entry_point[1] < height):
                            cv2.circle(vis_frame, tuple(entry_point), 3, (0, 255, 0), -1)
                            cv2.putText(vis_frame, f"#{track_id}",
                                       (entry_point[0] + 6, entry_point[1] - 3),
                                       cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0, 255, 0), 1)

                # Save frame data
                frame_results = {
                    'frame_idx': frame_idx,
                    'total_count': current_count,
                    'birds_detected': len(bird_detections),
                    'active_tracks': tracking_info['active_tracks']
                }
                all_results.append(frame_results)

                out.write(vis_frame)
                frame_idx += 1
                pbar.update(1)

            except Exception as e:
                print(f"Error at frame {frame_idx}: {e}")
                frame_idx += 1
                pbar.update(1)
                continue

    cap.release()
    out.release()

    # End processing
    final_birds_added = bird_tracker.process_end_of_video()
    final_count = bird_tracker.get_count()

    # Results
    final_results = {
        'summary': {
            'video_file': os.path.basename(video_path),
            'total_frames_processed': frame_idx,
            'total_birds_counted': final_count,
            'birds_added_at_end': final_birds_added,
            'method': 'simplified_multiple_bird_tracking'
        },
        'frame_by_frame': all_results,
        'roi_polygon': roi_polygon.tolist()
    }

    with open(output_json_path, "w") as f:
        json.dump(final_results, f, indent=4)

    print(f"\n✅ PROCESSING COMPLETE!")
    print(f"🐦 FINAL COUNT: {final_count} birds")
    print(f"📊 End-of-video adds: +{final_birds_added} birds")
    print(f"📹 Output video: {output_video_path}")
    print(f"📊 Results JSON: {output_json_path}")

    return final_results

# %%
# ============================================================================
# MAIN TESTING FUNCTIONS
# ============================================================================

def run_segment_test(segment_info, video_url):
    """Run tracker on a single segment"""
    segment_name = segment_info['name']
    start_time = segment_info['start']
    end_time = segment_info['end']
    expected_count = segment_info.get('expected_count', None)

    print(f"\n🔄 TESTING SEGMENT: {segment_name}")
    print(f"⏱️ Time range: {start_time} to {end_time}")
    print("-" * 50)

    try:
        # Download video segment (with caching)
        video_path, video_filename = download_video_segment_unique(
            video_url, start_time, end_time, segment_name
        )

        if not os.path.exists(video_path):
            raise Exception(f"Video file not found: {video_path}")

        # Run processing pipeline
        print(f"🤖 Running tracker on: {video_filename}")
        results = aggressive_bird_counting_pipeline(video_path, output_suffix=f"_{segment_name}")

        actual_count = results['summary']['total_birds_counted']

        # Calculate accuracy
        accuracy_info = {}
        if expected_count:
            accuracy_pct = (actual_count / expected_count) * 100
            difference = actual_count - expected_count
            accuracy_info = {
                'expected': expected_count,
                'actual': actual_count,
                'accuracy_percentage': accuracy_pct,
                'difference': difference,
                'status': 'EXCELLENT' if accuracy_pct >= 90 else 'GOOD' if accuracy_pct >= 80 else 'NEEDS_WORK'
            }

        return {
            'segment_name': segment_name,
            'time_range': f"{start_time} to {end_time}",
            'video_filename': video_filename,
            'model_count': actual_count,
            'accuracy_info': accuracy_info,
            'full_results': results,
            'success': True
        }

    except Exception as e:
        print(f"❌ Error in segment {segment_name}: {e}")
        return {
            'segment_name': segment_name,
            'time_range': f"{start_time} to {end_time}",
            'video_filename': 'N/A',
            'model_count': 0,
            'accuracy_info': {'status': 'ERROR'},
            'error': str(e),
            'success': False
        }

def display_comprehensive_summary(all_results):
    """Display detailed summary of all test results"""
    print(f"\n" + "="*85)
    print(f"📊 COMPREHENSIVE TEST RESULTS SUMMARY")
    print(f"="*85)

    print(f"{'Segment':<18} {'Time Range':<15} {'Expected':<10} {'Actual':<10} {'Accuracy':<12} {'Status':<15}")
    print(f"{'-'*18} {'-'*15} {'-'*10} {'-'*10} {'-'*12} {'-'*15}")

    total_expected = 0
    total_actual = 0
    successful_tests = 0

    for result in all_results:
        segment_name = result['segment_name'][:17]
        time_range = result['time_range'][:14]
        model_count = result['model_count']

        if result['success'] and result['accuracy_info'] and 'expected' in result['accuracy_info']:
            expected = result['accuracy_info']['expected']
            accuracy = f"{result['accuracy_info']['accuracy_percentage']:.1f}%"
            status = result['accuracy_info']['status']

            total_expected += expected
            total_actual += model_count
            successful_tests += 1

            print(f"{segment_name:<18} {time_range:<15} {expected:<10} {model_count:<10} {accuracy:<12} {status:<15}")
        else:
            status = "ERROR" if not result['success'] else "MODEL_ONLY"
            print(f"{segment_name:<18} {time_range:<15} {'N/A':<10} {model_count:<10} {'N/A':<12} {status:<15}")

    # Overall statistics
    if successful_tests > 0:
        overall_accuracy = (total_actual / total_expected) * 100
        print(f"{'-'*18} {'-'*15} {'-'*10} {'-'*10} {'-'*12} {'-'*15}")
        print(f"{'TOTAL':<18} {'ALL':<15} {total_expected:<10} {total_actual:<10} {overall_accuracy:.1f}{'%':<11} {'OVERALL':<15}")

        print(f"\n🎯 FINAL PERFORMANCE ANALYSIS:")
        print(f"   📊 Total birds expected: {total_expected}")
        print(f"   🐦 Total birds detected: {total_actual}")
        print(f"   📈 Overall accuracy: {overall_accuracy:.1f}%")
        print(f"   📉 Total difference: {total_actual - total_expected:+d} birds")

        # Performance rating
        if overall_accuracy >= 90:
            print(f"   🏆 Overall Rating: OUTSTANDING! 🥇")
        elif overall_accuracy >= 85:
            print(f"   ⭐ Overall Rating: EXCELLENT! ✨")
        elif overall_accuracy >= 75:
            print(f"   ✅ Overall Rating: GOOD")
        else:
            print(f"   ⚠️ Overall Rating: NEEDS IMPROVEMENT")

# %% [markdown]
# final

# %%
# ============================================================================
# MAIN EXECUTION
# ============================================================================

def run_all_tests():
    """Execute complete test suite"""
    print("🚀 STARTING BIRD CLASSIFICATION TESTING")
    print(f"📺 Video Source: {VIDEO_URL}")
    print(f"🧪 Testing {len(segments_to_test)} segments")
    print("=" * 80)

    # Run all tests
    all_test_results = []

    for i, segment in enumerate(segments_to_test, 1):
        print(f"\n🔬 TEST {i}/{len(segments_to_test)}")
        result = run_segment_test(segment, VIDEO_URL)
        all_test_results.append(result)

        # Show immediate results
        if result['success']:
            print(f"✅ {segment['name']}: {result['model_count']} birds detected")
            if result['accuracy_info'] and 'expected' in result['accuracy_info']:
                acc = result['accuracy_info']['accuracy_percentage']
                print(f"   Accuracy: {acc:.1f}% ({result['accuracy_info']['status']})")
        else:
            print(f"❌ {segment['name']}: Test failed")

    # Display comprehensive results
    display_comprehensive_summary(all_test_results)

    # Save master results
    master_results = {
        'test_metadata': {
            'test_date': str(datetime.now()),
            'video_url': VIDEO_URL,
            'total_segments': len(segments_to_test),
            'tracker_version': 'simplified_multiple_bird_v1'
        },
        'segment_configuration': segments_to_test,
        'test_results': all_test_results
    }

    master_results_path = f"{PATH}/data/master_test_results_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
    with open(master_results_path, 'w') as f:
        json.dump(master_results, f, indent=4)

    print(f"\n💾 Master results saved: {master_results_path}")
    print(f"🎉 COMPLETE TEST SUITE FINISHED!")

    return all_test_results

# ============================================================================
# USAGE EXAMPLES
# ============================================================================

print("✅ Cleaned Bird Classification Pipeline Loaded!")
print("\n🎯 USAGE:")
print("1. run_all_tests() - Execute complete test suite")
print("2. run_segment_test(segments_to_test[0], VIDEO_URL) - Test single segment")
print("\n💡 KEY IMPROVEMENTS:")
print("   • Video caching (no re-downloads)")
print("   • Simplified tracking logic")
print("   • Optimized for multiple birds")
print("   • Removed ~60% of unused code")
print("   • Clear function structure")

run_all_tests()
# Out:
# ✅ Cleaned Bird Classification Pipeline Loaded!
#
# 🎯 USAGE:
# 1. run_all_tests() - Execute complete test suite
# 2. run_segment_test(segments_to_test[0], VIDEO_URL) - Test single segment
#
# 💡 KEY IMPROVEMENTS:
#    • Video caching (no re-downloads)
#    • Simplified tracking logic
#    • Optimized for multiple birds
#    • Removed ~60% of unused code
#    • Clear function structure
# 🚀 STARTING BIRD CLASSIFICATION TESTING
# 📺 Video Source: https://www.youtube.com/watch?v=mkquDCpPD9c
# 🧪 Testing 1 segments
# ================================================================================
#
# 🔬 TEST 1/1
#
# 🔄 TESTING SEGMENT: original_working
# ⏱️ Time range: 0:05 to 0:16
# --------------------------------------------------
# ✅ Using existing file: downloaded_video_0-05_to_0-16.mp4
# 🤖 Running tracker on: downloaded_video_0-05_to_0-16.mp4
# 🎯 Bird Tracker initialized for multiple bird detection:
#    YOLO confidence: 0.08
#    ROI rectangle: (580,550) to (780,720)
#    Tracking zone: 150px radius
#    Track Recovery: ENABLED
# 📥 Downloading YOLO model...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/sam2_b.pt to 'sam2_b.pt'...
# 100%|██████████| 154M/154M [00:05<00:00, 31.0MB/s]
# 🎯 PROCESSING FOR MULTIPLE BIRDS
# 🎯 Video info: 264 total frames at 24.0 fps
# Processing multiple birds:   0%|          | 1/264 [00:09<42:05,  9.60s/it]
# 🔍 Frame 1: 1 detections, 0 in ROI, 1 active, 0 lost, 0 counted
# Processing multiple birds:   1%|          | 2/264 [00:09<18:03,  4.14s/it]
# 🔄 RECOVERED Track #1 after 0 frames
# 🔍 Frame 2: 1 detections, 1 in ROI, 1 active, 0 lost, 0 counted
# Processing multiple birds:   1%|          | 3/264 [00:10<10:23,  2.39s/it]
# 🔄 RECOVERED Track #1 after 0 frames
# 🐦 RECOVERED Bird #1 entered ROI at frame 3
# 🔍 Frame 3: 1 detections, 1 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:   2%|▏         | 4/264 [00:10<06:48,  1.57s/it]
# 🔄 RECOVERED Track #1 after 0 frames
# 🔍 Frame 4: 1 detections, 1 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:   2%|▏         | 5/264 [00:10<04:49,  1.12s/it]
# 🔄 RECOVERED Track #1 after 0 frames
# 🔍 Frame 5: 1 detections, 1 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:   3%|▎         | 9/264 [00:11<01:33,  2.72it/s]
# 🔄 RECOVERED Track #1 after 0 frames
# 🔍 Frame 6: 1 detections, 1 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  35%|███▌      | 93/264 [00:18<00:44,  3.80it/s]
# 🔍 Frame 93: 1 detections, 0 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  36%|███▌      | 94/264 [00:18<00:48,  3.52it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 94: 1 detections, 0 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  36%|███▌      | 95/264 [00:18<00:50,  3.35it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 95: 1 detections, 0 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  36%|███▋      | 96/264 [00:19<00:52,  3.23it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 96: 1 detections, 0 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  37%|███▋      | 97/264 [00:19<00:51,  3.21it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 97: 1 detections, 0 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  37%|███▋      | 98/264 [00:19<00:52,  3.18it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 98: 1 detections, 0 in ROI, 1 active, 0 lost, 1 counted
# Processing multiple birds:  38%|███▊      | 100/264 [00:20<00:53,  3.07it/s]
# 🔄 RECOVERED Track #2 after 1 frames
# 🐦 RECOVERED Bird #2 entered ROI at frame 100
# 🔍 Frame 100: 1 detections, 1 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  38%|███▊      | 101/264 [00:20<00:54,  2.97it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 101: 1 detections, 1 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  39%|███▊      | 102/264 [00:21<00:55,  2.90it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 102: 1 detections, 1 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  39%|███▉      | 103/264 [00:21<00:55,  2.88it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 103: 1 detections, 1 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  39%|███▉      | 104/264 [00:21<00:55,  2.88it/s]
# 🔄 RECOVERED Track #2 after 0 frames
# 🔍 Frame 104: 1 detections, 1 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  42%|████▏     | 112/264 [00:24<00:52,  2.88it/s]
# 🔍 Frame 112: 1 detections, 0 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  43%|████▎     | 113/264 [00:25<00:52,  2.85it/s]
# 🔄 RECOVERED Track #3 after 0 frames
# 🔍 Frame 113: 1 detections, 0 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  43%|████▎     | 114/264 [00:25<00:52,  2.85it/s]
# 🔄 RECOVERED Track #3 after 0 frames
# 🔍 Frame 114: 1 detections, 0 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  44%|████▎     | 115/264 [00:25<00:52,  2.84it/s]
# 🔄 RECOVERED Track #3 after 0 frames
# 🔍 Frame 115: 1 detections, 0 in ROI, 1 active, 0 lost, 2 counted
# Processing multiple birds:  44%|████▍     | 116/264 [00:26<00:53,  2.76it/s]
# 🔄 RECOVERED Track #3 after 0 frames
# 🐦 RECOVERED Bird #3 entered ROI at frame 116
# 🔍 Frame 116: 1 detections, 1 in ROI, 1 active, 0 lost, 3 counted
# Processing multiple birds:  44%|████▍     | 117/264 [00:26<00:53,  2.73it/s]
# 🔄 RECOVERED Track #3 after 0 frames
# 🔍 Frame 117: 1 detections, 1 in ROI, 1 active, 0 lost, 3 counted
# Processing multiple birds:  45%|████▍     | 118/264 [00:26<00:55,  2.64it/s]
# 🔄 RECOVERED Track #3 after 0 frames
# 🔍 Frame 118: 1 detections, 1 in ROI, 1 active, 0 lost, 3 counted
# Processing multiple birds:  47%|████▋     | 124/264 [00:29<01:04,  2.19it/s]
# 🔍 Frame 124: 1 detections, 0 in ROI, 1 active, 1 lost, 3 counted
# Processing multiple birds:  47%|████▋     | 125/264 [00:30<01:03,  2.19it/s]
# 🔄 RECOVERED Track #4 after 0 frames
# 🔍 Frame 125: 1 detections, 0 in ROI, 1 active, 0 lost, 3 counted
# Processing multiple birds:  48%|████▊     | 126/264 [00:30<01:03,  2.18it/s]
# 🔄 RECOVERED Track #4 after 0 frames
# 🔍 Frame 126: 1 detections, 0 in ROI, 1 active, 0 lost, 3 counted
# Processing multiple birds:  48%|████▊     | 127/264 [00:30<01:02,  2.19it/s]
# 🔄 RECOVERED Track #4 after 0 frames
# 🐦 RECOVERED Bird #4 entered ROI at frame 127
# 🔍 Frame 127: 1 detections, 1 in ROI, 1 active, 0 lost, 4 counted
# Processing multiple birds:  48%|████▊     | 128/264 [00:31<01:01,  2.20it/s]
# 🔄 RECOVERED Track #4 after 0 frames
# 🔍 Frame 128: 2 detections, 1 in ROI, 2 active, 0 lost, 4 counted
# Processing multiple birds:  49%|████▉     | 129/264 [00:31<01:00,  2.24it/s]
# 🔄 RECOVERED Track #5 after 0 frames
# 🔍 Frame 129: 3 detections, 2 in ROI, 3 active, 1 lost, 4 counted
# Processing multiple birds:  49%|████▉     | 130/264 [00:32<01:00,  2.23it/s]
# 🔄 RECOVERED Track #7 after 0 frames
# 🔄 RECOVERED Track #6 after 0 frames
# 🔍 Frame 130: 2 detections, 2 in ROI, 2 active, 2 lost, 4 counted
# Processing multiple birds:  50%|████▉     | 131/264 [00:32<01:00,  2.19it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔄 RECOVERED Track #7 after 0 frames
# 🐦 RECOVERED Bird #6 entered ROI at frame 131
# 🐦 RECOVERED Bird #7 entered ROI at frame 131
# 🔍 Frame 131: 2 detections, 2 in ROI, 2 active, 2 lost, 6 counted
# Processing multiple birds:  50%|█████     | 132/264 [00:33<01:00,  2.18it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔄 RECOVERED Track #7 after 0 frames
# 🔍 Frame 132: 2 detections, 2 in ROI, 2 active, 2 lost, 6 counted
# Processing multiple birds:  50%|█████     | 133/264 [00:33<00:59,  2.20it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔍 Frame 133: 2 detections, 1 in ROI, 2 active, 3 lost, 6 counted
# Processing multiple birds:  51%|█████     | 134/264 [00:34<00:57,  2.25it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔍 Frame 134: 1 detections, 1 in ROI, 1 active, 4 lost, 6 counted
# Processing multiple birds:  51%|█████     | 135/264 [00:34<00:57,  2.23it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔍 Frame 135: 2 detections, 2 in ROI, 2 active, 3 lost, 6 counted
# Processing multiple birds:  52%|█████▏    | 136/264 [00:35<00:58,  2.20it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔄 RECOVERED Track #9 after 0 frames
# 🔍 Frame 136: 3 detections, 2 in ROI, 3 active, 2 lost, 6 counted
# Processing multiple birds:  52%|█████▏    | 137/264 [00:35<00:57,  2.21it/s]
# 🔄 RECOVERED Track #10 after 0 frames
# 🔄 RECOVERED Track #6 after 0 frames
# 🔍 Frame 137: 2 detections, 2 in ROI, 2 active, 3 lost, 6 counted
# Processing multiple birds:  52%|█████▏    | 138/264 [00:35<00:56,  2.22it/s]
# 🔄 RECOVERED Track #10 after 0 frames
# 🔄 RECOVERED Track #6 after 0 frames
# 🐦 RECOVERED Bird #10 entered ROI at frame 138
# 🔍 Frame 138: 2 detections, 2 in ROI, 2 active, 3 lost, 7 counted
# Processing multiple birds:  53%|█████▎    | 139/264 [00:36<00:57,  2.17it/s]
# 🔄 RECOVERED Track #10 after 0 frames
# 🔄 RECOVERED Track #6 after 0 frames
# 🔍 Frame 139: 3 detections, 2 in ROI, 3 active, 2 lost, 7 counted
# Processing multiple birds:  53%|█████▎    | 140/264 [00:36<00:58,  2.12it/s]
# 🔄 RECOVERED Track #6 after 0 frames
# 🔄 RECOVERED Track #11 after 0 frames
# 🔍 Frame 140: 3 detections, 2 in ROI, 3 active, 2 lost, 7 counted
# Processing multiple birds:  53%|█████▎    | 141/264 [00:37<00:57,  2.13it/s]
# 🔄 RECOVERED Track #12 after 0 frames
# 🔍 Frame 141: 2 detections, 1 in ROI, 2 active, 4 lost, 7 counted
# Processing multiple birds:  54%|█████▍    | 142/264 [00:37<00:55,  2.20it/s]
# 🔄 RECOVERED Track #12 after 0 frames
# 🐦 RECOVERED Bird #12 entered ROI at frame 142
# 🔍 Frame 142: 1 detections, 1 in ROI, 1 active, 5 lost, 8 counted
# Processing multiple birds:  54%|█████▍    | 143/264 [00:38<00:56,  2.13it/s]
# 🔍 Frame 143: 2 detections, 0 in ROI, 2 active, 5 lost, 8 counted
# Processing multiple birds:  55%|█████▍    | 144/264 [00:38<00:57,  2.07it/s]
# 🔄 RECOVERED Track #14 after 0 frames
# 🔄 RECOVERED Track #15 after 0 frames
# 🔍 Frame 144: 2 detections, 0 in ROI, 2 active, 5 lost, 8 counted
# Processing multiple birds:  55%|█████▍    | 145/264 [00:39<00:56,  2.12it/s]
# 🔄 RECOVERED Track #14 after 0 frames
# 🔄 RECOVERED Track #15 after 0 frames
# 🐦 RECOVERED Bird #14 entered ROI at frame 145
# 🐦 RECOVERED Bird #15 entered ROI at frame 145
# 🔍 Frame 145: 2 detections, 2 in ROI, 2 active, 5 lost, 10 counted
# Processing multiple birds:  55%|█████▌    | 146/264 [00:39<00:58,  2.01it/s]
# 🔄 RECOVERED Track #14 after 0 frames
# 🔄 RECOVERED Track #15 after 0 frames
# 🔍 Frame 146: 2 detections, 2 in ROI, 2 active, 4 lost, 10 counted
# Processing multiple birds:  56%|█████▌    | 147/264 [00:40<01:00,  1.95it/s]
# 🔄 RECOVERED Track #14 after 0 frames
# 🔍 Frame 147: 1 detections, 1 in ROI, 1 active, 3 lost, 10 counted
# Processing multiple birds:  56%|█████▋    | 149/264 [00:41<01:06,  1.73it/s]
# 🔍 Frame 149: 1 detections, 0 in ROI, 1 active, 2 lost, 10 counted
# Processing multiple birds:  57%|█████▋    | 150/264 [00:42<01:07,  1.70it/s]
# 🔄 RECOVERED Track #16 after 0 frames
# 🔍 Frame 150: 1 detections, 0 in ROI, 1 active, 2 lost, 10 counted
# Processing multiple birds:  57%|█████▋    | 151/264 [00:42<01:07,  1.67it/s]
# 🔄 RECOVERED Track #16 after 0 frames
# 🔍 Frame 151: 1 detections, 0 in ROI, 1 active, 2 lost, 10 counted
# Processing multiple birds:  58%|█████▊    | 152/264 [00:43<01:11,  1.57it/s]
# 🔄 RECOVERED Track #16 after 0 frames
# 🔍 Frame 152: 4 detections, 1 in ROI, 4 active, 2 lost, 10 counted
# Processing multiple birds:  58%|█████▊    | 153/264 [00:44<01:09,  1.61it/s]
# 🔄 RECOVERED Track #19 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔄 RECOVERED Track #16 after 0 frames
# 🐦 RECOVERED Bird #16 entered ROI at frame 153
# 🔍 Frame 153: 4 detections, 2 in ROI, 4 active, 1 lost, 11 counted
# Processing multiple birds:  58%|█████▊    | 154/264 [00:44<01:05,  1.67it/s]
# 🔄 RECOVERED Track #19 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🐦 RECOVERED Bird #18 entered ROI at frame 154
# 🐦 RECOVERED Bird #17 entered ROI at frame 154
# 🔍 Frame 154: 3 detections, 2 in ROI, 3 active, 1 lost, 13 counted
# Processing multiple birds:  59%|█████▊    | 155/264 [00:45<01:04,  1.69it/s]
# 🔄 RECOVERED Track #18 after 0 frames
# 🔄 RECOVERED Track #19 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔍 Frame 155: 5 detections, 3 in ROI, 5 active, 1 lost, 13 counted
# Processing multiple birds:  59%|█████▉    | 156/264 [00:45<01:04,  1.69it/s]
# 🔄 RECOVERED Track #20 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔄 RECOVERED Track #21 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔄 RECOVERED Track #19 after 0 frames
# 🐦 RECOVERED Bird #19 entered ROI at frame 156
# 🔍 Frame 156: 5 detections, 3 in ROI, 5 active, 1 lost, 14 counted
# Processing multiple birds:  59%|█████▉    | 157/264 [00:46<01:02,  1.72it/s]
# 🔄 RECOVERED Track #20 after 0 frames
# 🔄 RECOVERED Track #21 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔄 RECOVERED Track #19 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔍 Frame 157: 6 detections, 3 in ROI, 6 active, 1 lost, 14 counted
# Processing multiple birds:  60%|█████▉    | 158/264 [00:47<01:01,  1.72it/s]
# 🔄 RECOVERED Track #22 after 0 frames
# 🔄 RECOVERED Track #19 after 0 frames
# 🔄 RECOVERED Track #20 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔍 Frame 158: 6 detections, 2 in ROI, 6 active, 2 lost, 14 counted
# Processing multiple birds:  60%|██████    | 159/264 [00:47<00:58,  1.78it/s]
# 🔄 RECOVERED Track #22 after 0 frames
# 🔄 RECOVERED Track #23 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔍 Frame 159: 5 detections, 2 in ROI, 5 active, 4 lost, 14 counted
# Processing multiple birds:  61%|██████    | 160/264 [00:48<00:57,  1.82it/s]
# 🔄 RECOVERED Track #22 after 0 frames
# 🔄 RECOVERED Track #17 after 0 frames
# 🔄 RECOVERED Track #18 after 0 frames
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #23 after 0 frames
# 🐦 RECOVERED Bird #23 entered ROI at frame 160
# 🔍 Frame 160: 5 detections, 2 in ROI, 5 active, 3 lost, 15 counted
# Processing multiple birds:  61%|██████    | 161/264 [00:48<00:56,  1.82it/s]
# 🔄 RECOVERED Track #22 after 0 frames
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #23 after 0 frames
# 🐦 RECOVERED Bird #24 entered ROI at frame 161
# 🔍 Frame 161: 4 detections, 3 in ROI, 4 active, 5 lost, 16 counted
# Processing multiple birds:  61%|██████▏   | 162/264 [00:49<00:55,  1.83it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #23 after 0 frames
# 🔄 RECOVERED Track #25 after 0 frames
# 🔍 Frame 162: 4 detections, 3 in ROI, 4 active, 6 lost, 16 counted
# Processing multiple birds:  62%|██████▏   | 163/264 [00:49<00:55,  1.81it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #26 after 0 frames
# 🔄 RECOVERED Track #25 after 0 frames
# 🔄 RECOVERED Track #23 after 0 frames
# 🐦 RECOVERED Bird #25 entered ROI at frame 163
# 🔍 Frame 163: 4 detections, 3 in ROI, 4 active, 6 lost, 17 counted
# Processing multiple birds:  62%|██████▏   | 164/264 [00:50<00:55,  1.79it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #25 after 0 frames
# 🔄 RECOVERED Track #26 after 0 frames
# 🐦 RECOVERED Bird #26 entered ROI at frame 164
# 🔍 Frame 164: 3 detections, 2 in ROI, 3 active, 6 lost, 18 counted
# Processing multiple birds:  62%|██████▎   | 165/264 [00:50<00:55,  1.78it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #26 after 0 frames
# 🔄 RECOVERED Track #25 after 0 frames
# 🔍 Frame 165: 3 detections, 2 in ROI, 3 active, 4 lost, 18 counted
# Processing multiple birds:  63%|██████▎   | 166/264 [00:51<00:56,  1.74it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #25 after 0 frames
# 🔄 RECOVERED Track #26 after 0 frames
# 🔍 Frame 166: 5 detections, 2 in ROI, 5 active, 4 lost, 18 counted
# Processing multiple birds:  63%|██████▎   | 167/264 [00:52<00:55,  1.75it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #27 after 0 frames
# 🔍 Frame 167: 2 detections, 2 in ROI, 2 active, 5 lost, 18 counted
# Processing multiple birds:  64%|██████▎   | 168/264 [00:52<00:54,  1.77it/s]
# 🔄 RECOVERED Track #24 after 0 frames
# 🔄 RECOVERED Track #27 after 0 frames
# 🐦 RECOVERED Bird #27 entered ROI at frame 168
# 🔍 Frame 168: 2 detections, 2 in ROI, 2 active, 4 lost, 19 counted
# Processing multiple birds:  64%|██████▍   | 169/264 [00:53<00:53,  1.79it/s]
# 🔄 RECOVERED Track #27 after 0 frames
# 🔍 Frame 169: 1 detections, 1 in ROI, 1 active, 5 lost, 19 counted
# Processing multiple birds:  64%|██████▍   | 170/264 [00:53<00:51,  1.83it/s]
# 🔄 RECOVERED Track #27 after 0 frames
# 🔍 Frame 170: 3 detections, 1 in ROI, 3 active, 4 lost, 19 counted
# Processing multiple birds:  65%|██████▍   | 171/264 [00:54<00:53,  1.73it/s]
# 🔄 RECOVERED Track #30 after 0 frames
# 🔄 RECOVERED Track #27 after 0 frames
# 🔍 Frame 171: 3 detections, 1 in ROI, 3 active, 5 lost, 19 counted
# Processing multiple birds:  65%|██████▌   | 172/264 [00:54<00:54,  1.70it/s]
# 🔄 RECOVERED Track #30 after 0 frames
# 🔄 RECOVERED Track #27 after 0 frames
# 🔄 RECOVERED Track #31 after 0 frames
# 🐦 RECOVERED Bird #30 entered ROI at frame 172
# 🔍 Frame 172: 3 detections, 2 in ROI, 3 active, 5 lost, 20 counted
# Processing multiple birds:  66%|██████▌   | 173/264 [00:55<00:54,  1.66it/s]
# 🔄 RECOVERED Track #30 after 0 frames
# 🔄 RECOVERED Track #31 after 0 frames
# 🔍 Frame 173: 4 detections, 1 in ROI, 4 active, 3 lost, 20 counted
# Processing multiple birds:  66%|██████▌   | 174/264 [00:56<00:54,  1.64it/s]
# 🔄 RECOVERED Track #30 after 0 frames
# 🔄 RECOVERED Track #32 after 0 frames
# 🔄 RECOVERED Track #33 after 0 frames
# 🔍 Frame 174: 4 detections, 1 in ROI, 4 active, 4 lost, 20 counted
# Processing multiple birds:  66%|██████▋   | 175/264 [00:56<00:57,  1.55it/s]
# 🔄 RECOVERED Track #34 after 0 frames
# 🔄 RECOVERED Track #30 after 0 frames
# 🔄 RECOVERED Track #32 after 0 frames
# 🔍 Frame 175: 6 detections, 1 in ROI, 6 active, 4 lost, 20 counted
# Processing multiple birds:  67%|██████▋   | 176/264 [00:57<00:54,  1.62it/s]
# 🔄 RECOVERED Track #34 after 0 frames
# 🔄 RECOVERED Track #36 after 0 frames
# 🔄 RECOVERED Track #32 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🐦 RECOVERED Bird #32 entered ROI at frame 176
# 🔍 Frame 176: 4 detections, 2 in ROI, 4 active, 6 lost, 21 counted
# Processing multiple birds:  67%|██████▋   | 177/264 [00:58<00:52,  1.66it/s]
# 🔄 RECOVERED Track #32 after 0 frames
# 🔄 RECOVERED Track #34 after 0 frames
# 🔄 RECOVERED Track #35 after 1 frames
# 🔄 RECOVERED Track #36 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🐦 RECOVERED Bird #36 entered ROI at frame 177
# 🐦 RECOVERED Bird #37 entered ROI at frame 177
# 🔍 Frame 177: 6 detections, 4 in ROI, 6 active, 4 lost, 23 counted
# Processing multiple birds:  67%|██████▋   | 178/264 [00:58<00:51,  1.68it/s]
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #35 after 0 frames
# 🔄 RECOVERED Track #36 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🐦 RECOVERED Bird #35 entered ROI at frame 178
# 🔍 Frame 178: 4 detections, 4 in ROI, 4 active, 6 lost, 24 counted
# Processing multiple birds:  68%|██████▊   | 179/264 [00:59<00:49,  1.70it/s]
# 🔄 RECOVERED Track #35 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🐦 RECOVERED Bird #38 entered ROI at frame 179
# 🔍 Frame 179: 4 detections, 2 in ROI, 4 active, 6 lost, 25 counted
# Processing multiple birds:  68%|██████▊   | 180/264 [00:59<00:49,  1.71it/s]
# 🔄 RECOVERED Track #39 after 0 frames
# 🔄 RECOVERED Track #35 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🔍 Frame 180: 4 detections, 2 in ROI, 4 active, 5 lost, 25 counted
# Processing multiple birds:  69%|██████▊   | 181/264 [01:00<00:47,  1.73it/s]
# 🔄 RECOVERED Track #39 after 0 frames
# 🔄 RECOVERED Track #35 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔍 Frame 181: 5 detections, 1 in ROI, 5 active, 4 lost, 25 counted
# Processing multiple birds:  69%|██████▉   | 182/264 [01:00<00:47,  1.71it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #39 after 0 frames
# 🔍 Frame 182: 4 detections, 2 in ROI, 4 active, 4 lost, 25 counted
# Processing multiple birds:  69%|██████▉   | 183/264 [01:01<00:47,  1.70it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #39 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🐦 RECOVERED Bird #39 entered ROI at frame 183
# 🔍 Frame 183: 4 detections, 3 in ROI, 4 active, 4 lost, 26 counted
# Processing multiple birds:  70%|██████▉   | 184/264 [01:02<00:46,  1.70it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #37 after 0 frames
# 🔄 RECOVERED Track #39 after 0 frames
# 🔍 Frame 184: 5 detections, 4 in ROI, 5 active, 2 lost, 26 counted
# Processing multiple birds:  70%|███████   | 185/264 [01:02<00:45,  1.73it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #41 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #39 after 0 frames
# 🔍 Frame 185: 4 detections, 3 in ROI, 4 active, 2 lost, 26 counted
# Processing multiple birds:  70%|███████   | 186/264 [01:03<00:44,  1.75it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #41 after 0 frames
# 🔄 RECOVERED Track #38 after 0 frames
# 🔄 RECOVERED Track #39 after 0 frames
# 🐦 RECOVERED Bird #41 entered ROI at frame 186
# 🔍 Frame 186: 4 detections, 3 in ROI, 4 active, 2 lost, 27 counted
# Processing multiple birds:  71%|███████   | 187/264 [01:03<00:42,  1.83it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #41 after 0 frames
# 🐦 RECOVERED Bird #40 entered ROI at frame 187
# 🔍 Frame 187: 2 detections, 2 in ROI, 2 active, 4 lost, 28 counted
# Processing multiple birds:  71%|███████   | 188/264 [01:04<00:40,  1.87it/s]
# 🔄 RECOVERED Track #40 after 0 frames
# 🔄 RECOVERED Track #41 after 0 frames
# 🔍 Frame 188: 2 detections, 2 in ROI, 2 active, 3 lost, 28 counted
# Processing multiple birds:  72%|███████▏  | 189/264 [01:04<00:39,  1.90it/s]
# 🔄 RECOVERED Track #41 after 0 frames
# 🔍 Frame 189: 1 detections, 0 in ROI, 1 active, 4 lost, 28 counted
# Processing multiple birds:  72%|███████▏  | 190/264 [01:05<00:38,  1.94it/s]
# 🔍 Frame 190: 1 detections, 0 in ROI, 1 active, 5 lost, 28 counted
# Processing multiple birds:  72%|███████▏  | 191/264 [01:05<00:36,  1.98it/s]
# 🔄 RECOVERED Track #42 after 0 frames
# 🔍 Frame 191: 2 detections, 1 in ROI, 2 active, 4 lost, 28 counted
# Processing multiple birds:  73%|███████▎  | 192/264 [01:06<00:35,  2.02it/s]
# 🔄 RECOVERED Track #42 after 0 frames
# 🔄 RECOVERED Track #43 after 0 frames
# 🔍 Frame 192: 2 detections, 1 in ROI, 2 active, 4 lost, 28 counted
# Processing multiple birds:  73%|███████▎  | 193/264 [01:06<00:34,  2.03it/s]
# 🔄 RECOVERED Track #43 after 0 frames
# 🔄 RECOVERED Track #42 after 0 frames
# 🐦 RECOVERED Bird #43 entered ROI at frame 193
# 🐦 RECOVERED Bird #42 entered ROI at frame 193
# 🔍 Frame 193: 2 detections, 2 in ROI, 2 active, 2 lost, 30 counted
# Processing multiple birds:  73%|███████▎  | 194/264 [01:07<00:36,  1.94it/s]
# 🔄 RECOVERED Track #42 after 0 frames
# 🔍 Frame 194: 1 detections, 1 in ROI, 1 active, 3 lost, 30 counted
# Processing multiple birds:  74%|███████▍  | 195/264 [01:07<00:38,  1.81it/s]
# 🔄 RECOVERED Track #42 after 0 frames
# 🔍 Frame 195: 1 detections, 1 in ROI, 1 active, 2 lost, 30 counted
# Processing multiple birds:  75%|███████▍  | 197/264 [01:09<00:38,  1.75it/s]
# 🔍 Frame 197: 3 detections, 0 in ROI, 3 active, 2 lost, 30 counted
# Processing multiple birds:  75%|███████▌  | 198/264 [01:09<00:38,  1.70it/s]
# 🔄 RECOVERED Track #44 after 0 frames
# 🔄 RECOVERED Track #45 after 0 frames
# 🔄 RECOVERED Track #46 after 0 frames
# 🔍 Frame 198: 3 detections, 0 in ROI, 3 active, 2 lost, 30 counted
# Processing multiple birds:  75%|███████▌  | 199/264 [01:10<00:38,  1.70it/s]
# 🔄 RECOVERED Track #46 after 0 frames
# 🔄 RECOVERED Track #44 after 0 frames
# 🐦 RECOVERED Bird #46 entered ROI at frame 199
# 🐦 RECOVERED Bird #44 entered ROI at frame 199
# 🔍 Frame 199: 2 detections, 2 in ROI, 2 active, 3 lost, 32 counted
# Processing multiple birds:  76%|███████▌  | 200/264 [01:10<00:35,  1.79it/s]
# 🔄 RECOVERED Track #44 after 0 frames
# 🔍 Frame 200: 3 detections, 2 in ROI, 3 active, 3 lost, 32 counted
# Processing multiple birds:  76%|███████▌  | 201/264 [01:11<00:33,  1.88it/s]
# 🔄 RECOVERED Track #47 after 0 frames
# 🔍 Frame 201: 2 detections, 1 in ROI, 2 active, 5 lost, 32 counted
# Processing multiple birds:  77%|███████▋  | 202/264 [01:11<00:31,  1.96it/s]
# 🔄 RECOVERED Track #49 after 0 frames
# 🔍 Frame 202: 2 detections, 1 in ROI, 2 active, 5 lost, 32 counted
# Processing multiple birds:  77%|███████▋  | 203/264 [01:12<00:30,  2.01it/s]
# 🔄 RECOVERED Track #50 after 0 frames
# 🔍 Frame 203: 2 detections, 1 in ROI, 2 active, 6 lost, 32 counted
# Processing multiple birds:  77%|███████▋  | 204/264 [01:12<00:29,  2.05it/s]
# 🔄 RECOVERED Track #51 after 0 frames
# 🔄 RECOVERED Track #50 after 0 frames
# 🐦 RECOVERED Bird #50 entered ROI at frame 204
# 🔍 Frame 204: 2 detections, 1 in ROI, 2 active, 6 lost, 33 counted
# Processing multiple birds:  78%|███████▊  | 205/264 [01:12<00:27,  2.13it/s]
# 🔄 RECOVERED Track #51 after 0 frames
# 🔄 RECOVERED Track #50 after 0 frames
# 🔍 Frame 205: 2 detections, 0 in ROI, 2 active, 5 lost, 33 counted
# Processing multiple birds:  78%|███████▊  | 206/264 [01:13<00:26,  2.16it/s]
# 🔄 RECOVERED Track #51 after 0 frames
# 🔍 Frame 206: 3 detections, 1 in ROI, 3 active, 5 lost, 33 counted
# Processing multiple birds:  78%|███████▊  | 207/264 [01:13<00:26,  2.18it/s]
# 🔄 RECOVERED Track #52 after 0 frames
# 🔄 RECOVERED Track #53 after 0 frames
# 🔍 Frame 207: 3 detections, 2 in ROI, 3 active, 4 lost, 33 counted
# Processing multiple birds:  79%|███████▉  | 208/264 [01:14<00:24,  2.25it/s]
# 🔄 RECOVERED Track #52 after 0 frames
# 🔄 RECOVERED Track #54 after 0 frames
# 🐦 RECOVERED Bird #52 entered ROI at frame 208
# 🔍 Frame 208: 2 detections, 2 in ROI, 2 active, 4 lost, 34 counted
# Processing multiple birds:  79%|███████▉  | 209/264 [01:14<00:24,  2.28it/s]
# 🔄 RECOVERED Track #52 after 0 frames
# 🔍 Frame 209: 1 detections, 1 in ROI, 1 active, 4 lost, 34 counted
# Processing multiple birds:  80%|███████▉  | 210/264 [01:15<00:23,  2.30it/s]
# 🔄 RECOVERED Track #52 after 0 frames
# 🔍 Frame 210: 1 detections, 1 in ROI, 1 active, 4 lost, 34 counted
# Processing multiple birds:  80%|████████  | 212/264 [01:15<00:20,  2.50it/s]
# 🔍 Frame 212: 1 detections, 0 in ROI, 1 active, 4 lost, 34 counted
# Processing multiple birds:  81%|████████  | 213/264 [01:16<00:20,  2.46it/s]
# 🔄 RECOVERED Track #55 after 0 frames
# 🔍 Frame 213: 2 detections, 0 in ROI, 2 active, 3 lost, 34 counted
# Processing multiple birds:  81%|████████  | 214/264 [01:16<00:20,  2.47it/s]
# 🔄 RECOVERED Track #56 after 0 frames
# 🔄 RECOVERED Track #55 after 0 frames
# 🐦 RECOVERED Bird #55 entered ROI at frame 214
# 🔍 Frame 214: 3 detections, 3 in ROI, 3 active, 2 lost, 35 counted
# Processing multiple birds:  81%|████████▏ | 215/264 [01:17<00:19,  2.52it/s]
# 🔄 RECOVERED Track #56 after 0 frames
# 🐦 RECOVERED Bird #56 entered ROI at frame 215
# 🔍 Frame 215: 1 detections, 1 in ROI, 1 active, 3 lost, 36 counted
# Processing multiple birds:  82%|████████▏ | 216/264 [01:17<00:18,  2.57it/s]
# 🔄 RECOVERED Track #56 after 0 frames
# 🔍 Frame 216: 1 detections, 1 in ROI, 1 active, 3 lost, 36 counted
# Processing multiple birds:  82%|████████▏ | 217/264 [01:17<00:18,  2.60it/s]
# 🔄 RECOVERED Track #56 after 0 frames
# 🔍 Frame 217: 1 detections, 1 in ROI, 1 active, 2 lost, 36 counted
# Processing multiple birds:  83%|████████▎ | 218/264 [01:18<00:17,  2.63it/s]
# 🔄 RECOVERED Track #56 after 0 frames
# 🔍 Frame 218: 1 detections, 1 in ROI, 1 active, 2 lost, 36 counted
# Processing multiple birds:  83%|████████▎ | 219/264 [01:18<00:16,  2.68it/s]
# 🔍 Frame 219: 1 detections, 0 in ROI, 1 active, 3 lost, 36 counted
# Processing multiple birds:  83%|████████▎ | 220/264 [01:18<00:16,  2.71it/s]
# 🔄 RECOVERED Track #58 after 0 frames
# 🔍 Frame 220: 1 detections, 0 in ROI, 1 active, 3 lost, 36 counted
# Processing multiple birds:  84%|████████▎ | 221/264 [01:19<00:15,  2.72it/s]
# 🔄 RECOVERED Track #58 after 0 frames
# 🐦 RECOVERED Bird #58 entered ROI at frame 221
# 🔍 Frame 221: 1 detections, 1 in ROI, 1 active, 1 lost, 37 counted
# Processing multiple birds:  84%|████████▍ | 222/264 [01:19<00:15,  2.74it/s]
# 🔄 RECOVERED Track #58 after 0 frames
# 🔍 Frame 222: 1 detections, 1 in ROI, 1 active, 1 lost, 37 counted
# Processing multiple birds:  84%|████████▍ | 223/264 [01:19<00:14,  2.79it/s]
# 🔄 RECOVERED Track #58 after 0 frames
# 🔍 Frame 223: 1 detections, 1 in ROI, 1 active, 1 lost, 37 counted
# Processing multiple birds:  85%|████████▍ | 224/264 [01:20<00:15,  2.65it/s]
# 🔄 RECOVERED Track #58 after 0 frames
# 🔍 Frame 224: 2 detections, 1 in ROI, 2 active, 1 lost, 37 counted
# Processing multiple birds:  85%|████████▌ | 225/264 [01:20<00:14,  2.62it/s]
# 🔄 RECOVERED Track #59 after 0 frames
# 🔍 Frame 225: 2 detections, 1 in ROI, 2 active, 1 lost, 37 counted
# Processing multiple birds:  86%|████████▌ | 226/264 [01:21<00:14,  2.61it/s]
# 🔄 RECOVERED Track #60 after 0 frames
# 🔄 RECOVERED Track #59 after 0 frames
# 🐦 RECOVERED Bird #59 entered ROI at frame 226
# 🔍 Frame 226: 2 detections, 2 in ROI, 2 active, 1 lost, 38 counted
# Processing multiple birds:  86%|████████▌ | 227/264 [01:21<00:14,  2.61it/s]
# 🔄 RECOVERED Track #60 after 0 frames
# 🐦 RECOVERED Bird #60 entered ROI at frame 227
# 🔍 Frame 227: 1 detections, 1 in ROI, 1 active, 2 lost, 39 counted
# Processing multiple birds:  87%|████████▋ | 230/264 [01:22<00:07,  4.40it/s]
# 🔄 RECOVERED Track #60 after 0 frames
# 🔍 Frame 228: 1 detections, 1 in ROI, 1 active, 2 lost, 39 counted
# Processing multiple birds: 100%|██████████| 264/264 [01:23<00:00,  3.15it/s]
# 🏁 End-of-video processing - checking 0 tracks...
#
# ✅ PROCESSING COMPLETE!
# 🐦 FINAL COUNT: 39 birds
# 📊 End-of-video adds: +0 birds
# 📹 Output video: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments/data/sam2_output_downloaded_video_0-05_to_0-16_original_working.mp4
# 📊 Results JSON: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments/data/sam2_results_downloaded_video_0-05_to_0-16_original_working.json
# ✅ original_working: 39 birds detected
#    Accuracy: 83.0% (GOOD)
#
# =====================================================================================
# 📊 COMPREHENSIVE TEST RESULTS SUMMARY
# =====================================================================================
# Segment            Time Range      Expected   Actual     Accuracy     Status
# ------------------ --------------- ---------- ---------- ------------ ---------------
# original_working   0:05 to 0:16    47         39         83.0%        GOOD
# ------------------ --------------- ---------- ---------- ------------ ---------------
# TOTAL              ALL             47         39         83.0%           OVERALL
#
# 🎯 FINAL PERFORMANCE ANALYSIS:
#    📊 Total birds expected: 47
#    🐦 Total birds detected: 39
#    📈 Overall accuracy: 83.0%
#    📉 Total difference: -8 birds
#    ✅ Overall Rating: GOOD
#
# 💾 Master results saved: drive/MyDrive/UW-MS-DS/CSE493G1/Final_Project/Github/swiftcounter-cv/experiments/data/master_test_results_20250608_002730.json
# 🎉 COMPLETE TEST SUITE FINISHED!
# [{'segment_name': 'original_working',
#   'time_range': '0:05 to 0:16',
#   'video_filename': 'downloaded_video_0-05_to_0-16.mp4',
#   'model_count': 39,
#   'accuracy_info': {'expected': 47,
#    'actual': 39,
#    'accuracy_percentage': 82.97872340425532,
#    'difference': -8,
#    'status': 'GOOD'},
#   'full_results': {'summary': {'video_file': 'downloaded_video_0-05_to_0-16.mp4',
#     'total_frames_processed': 264,
#     'total_birds_counted': 39,
#     'birds_added_at_end': 0,
#     'method': 'simplified_multiple_bird_tracking'},
#    'frame_by_frame': [{'frame_idx': 0,
#      'total_count': 0,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 1,
#      'total_count': 0,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 2,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 3,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 4,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 5,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 6,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 7,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 8,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 9,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 10,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 11,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 12,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 13,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 14,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 15,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 16,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 17,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 18,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 19,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 20,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 21,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 22,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 23,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 24,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 25,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 26,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 27,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 28,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 29,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 30,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 31,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 32,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 33,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 34,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 35,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 36,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 37,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 38,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 39,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 40,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 41,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 42,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 43,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 44,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 45,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 46,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 47,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 48,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 49,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 50,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 51,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 52,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 53,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 54,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 0},
#     {'frame_idx': 55,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 56,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 57,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 58,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 59,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 60,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 61,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 62,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 63,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 64,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 65,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 66,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 67,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 68,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 69,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 0},
#     {'frame_idx': 70,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 71,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 72,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 73,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 74,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 75,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 76,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 77,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 78,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 79,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 0},
#     {'frame_idx': 80,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 81,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 0},
#     {'frame_idx': 82,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 83,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 84,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 85,
#      'total_count': 1,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 86,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 0},
#     {'frame_idx': 87,
#      'total_count': 1,
#      'birds_detected': 3,
#      'active_tracks': 0},
#     {'frame_idx': 88,
#      'total_count': 1,
#      'birds_detected': 2,
#      'active_tracks': 0},
#     {'frame_idx': 89,
#      'total_count': 1,
#      'birds_detected': 2,
#      'active_tracks': 0},
#     {'frame_idx': 90,
#      'total_count': 1,
#      'birds_detected': 2,
#      'active_tracks': 0},
#     {'frame_idx': 91,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 0},
#     {'frame_idx': 92,
#      'total_count': 1,
#      'birds_detected': 2,
#      'active_tracks': 1},
#     {'frame_idx': 93,
#      'total_count': 1,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 94,
#      'total_count': 1,
#      'birds_detected': 4,
#      'active_tracks': 1},
#     {'frame_idx': 95,
#      'total_count': 1,
#      'birds_detected': 4,
#      'active_tracks': 1},
#     {'frame_idx': 96,
#      'total_count': 1,
#      'birds_detected': 1,
#      'active_tracks': 1},
#     {'frame_idx': 97,
#      'total_count': 1,
#      'birds_detected': 2,
#      'active_tracks': 1},
#     {'frame_idx': 98,
#      'total_count': 1,
#      'birds_detected': 2,
#      'active_tracks': 0},
#     {'frame_idx': 99,
#      'total_count': 2,
#      'birds_detected': 4,
#      'active_tracks': 1},
#     {'frame_idx': 100,
#      'total_count': 2,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 101,
#      'total_count': 2,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 102,
#      'total_count': 2,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 103,
#      'total_count': 2,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 104,
#      'total_count': 2,
#      'birds_detected': 3,
#      'active_tracks': 0},
#     {'frame_idx': 105,
#      'total_count': 2,
#      'birds_detected': 2,
#      'active_tracks': 0},
#     {'frame_idx': 106,
#      'total_count': 2,
#      'birds_detected': 3,
#      'active_tracks': 0},
#     {'frame_idx': 107,
#      'total_count': 2,
#      'birds_detected': 3,
#      'active_tracks': 0},
#     {'frame_idx': 108,
#      'total_count': 2,
#      'birds_detected': 2,
#      'active_tracks': 0},
#     {'frame_idx': 109,
#      'total_count': 2,
#      'birds_detected': 3,
#      'active_tracks': 0},
#     {'frame_idx': 110,
#      'total_count': 2,
#      'birds_detected': 6,
#      'active_tracks': 0},
#     {'frame_idx': 111,
#      'total_count': 2,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 112,
#      'total_count': 2,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 113,
#      'total_count': 2,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 114,
#      'total_count': 2,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 115,
#      'total_count': 3,
#      'birds_detected': 7,
#      'active_tracks': 1},
#     {'frame_idx': 116,
#      'total_count': 3,
#      'birds_detected': 7,
#      'active_tracks': 1},
#     {'frame_idx': 117,
#      'total_count': 3,
#      'birds_detected': 9,
#      'active_tracks': 1},
#     {'frame_idx': 118,
#      'total_count': 3,
#      'birds_detected': 7,
#      'active_tracks': 0},
#     {'frame_idx': 119,
#      'total_count': 3,
#      'birds_detected': 7,
#      'active_tracks': 0},
#     {'frame_idx': 120,
#      'total_count': 3,
#      'birds_detected': 10,
#      'active_tracks': 0},
#     {'frame_idx': 121,
#      'total_count': 3,
#      'birds_detected': 8,
#      'active_tracks': 0},
#     {'frame_idx': 122,
#      'total_count': 3,
#      'birds_detected': 10,
#      'active_tracks': 0},
#     {'frame_idx': 123,
#      'total_count': 3,
#      'birds_detected': 11,
#      'active_tracks': 1},
#     {'frame_idx': 124,
#      'total_count': 3,
#      'birds_detected': 9,
#      'active_tracks': 1},
#     {'frame_idx': 125,
#      'total_count': 3,
#      'birds_detected': 9,
#      'active_tracks': 1},
#     {'frame_idx': 126,
#      'total_count': 4,
#      'birds_detected': 12,
#      'active_tracks': 1},
#     {'frame_idx': 127,
#      'total_count': 4,
#      'birds_detected': 12,
#      'active_tracks': 2},
#     {'frame_idx': 128,
#      'total_count': 4,
#      'birds_detected': 10,
#      'active_tracks': 3},
#     {'frame_idx': 129,
#      'total_count': 4,
#      'birds_detected': 13,
#      'active_tracks': 2},
#     {'frame_idx': 130,
#      'total_count': 6,
#      'birds_detected': 14,
#      'active_tracks': 2},
#     {'frame_idx': 131,
#      'total_count': 6,
#      'birds_detected': 14,
#      'active_tracks': 2},
#     {'frame_idx': 132,
#      'total_count': 6,
#      'birds_detected': 12,
#      'active_tracks': 2},
#     {'frame_idx': 133,
#      'total_count': 6,
#      'birds_detected': 10,
#      'active_tracks': 1},
#     {'frame_idx': 134,
#      'total_count': 6,
#      'birds_detected': 13,
#      'active_tracks': 2},
#     {'frame_idx': 135,
#      'total_count': 6,
#      'birds_detected': 13,
#      'active_tracks': 3},
#     {'frame_idx': 136,
#      'total_count': 6,
#      'birds_detected': 12,
#      'active_tracks': 2},
#     {'frame_idx': 137,
#      'total_count': 7,
#      'birds_detected': 12,
#      'active_tracks': 2},
#     {'frame_idx': 138,
#      'total_count': 7,
#      'birds_detected': 15,
#      'active_tracks': 3},
#     {'frame_idx': 139,
#      'total_count': 7,
#      'birds_detected': 15,
#      'active_tracks': 3},
#     {'frame_idx': 140,
#      'total_count': 7,
#      'birds_detected': 14,
#      'active_tracks': 2},
#     {'frame_idx': 141,
#      'total_count': 8,
#      'birds_detected': 10,
#      'active_tracks': 1},
#     {'frame_idx': 142,
#      'total_count': 8,
#      'birds_detected': 17,
#      'active_tracks': 2},
#     {'frame_idx': 143,
#      'total_count': 8,
#      'birds_detected': 17,
#      'active_tracks': 2},
#     {'frame_idx': 144,
#      'total_count': 10,
#      'birds_detected': 12,
#      'active_tracks': 2},
#     {'frame_idx': 145,
#      'total_count': 10,
#      'birds_detected': 20,
#      'active_tracks': 2},
#     {'frame_idx': 146,
#      'total_count': 10,
#      'birds_detected': 21,
#      'active_tracks': 1},
#     {'frame_idx': 147,
#      'total_count': 10,
#      'birds_detected': 21,
#      'active_tracks': 0},
#     {'frame_idx': 148,
#      'total_count': 10,
#      'birds_detected': 18,
#      'active_tracks': 1},
#     {'frame_idx': 149,
#      'total_count': 10,
#      'birds_detected': 18,
#      'active_tracks': 1},
#     {'frame_idx': 150,
#      'total_count': 10,
#      'birds_detected': 18,
#      'active_tracks': 1},
#     {'frame_idx': 151,
#      'total_count': 10,
#      'birds_detected': 22,
#      'active_tracks': 4},
#     {'frame_idx': 152,
#      'total_count': 11,
#      'birds_detected': 21,
#      'active_tracks': 4},
#     {'frame_idx': 153,
#      'total_count': 13,
#      'birds_detected': 19,
#      'active_tracks': 3},
#     {'frame_idx': 154,
#      'total_count': 13,
#      'birds_detected': 23,
#      'active_tracks': 5},
#     {'frame_idx': 155,
#      'total_count': 14,
#      'birds_detected': 23,
#      'active_tracks': 5},
#     {'frame_idx': 156,
#      'total_count': 14,
#      'birds_detected': 19,
#      'active_tracks': 6},
#     {'frame_idx': 157,
#      'total_count': 14,
#      'birds_detected': 21,
#      'active_tracks': 6},
#     {'frame_idx': 158,
#      'total_count': 14,
#      'birds_detected': 17,
#      'active_tracks': 5},
#     {'frame_idx': 159,
#      'total_count': 15,
#      'birds_detected': 17,
#      'active_tracks': 5},
#     {'frame_idx': 160,
#      'total_count': 16,
#      'birds_detected': 18,
#      'active_tracks': 4},
#     {'frame_idx': 161,
#      'total_count': 16,
#      'birds_detected': 18,
#      'active_tracks': 4},
#     {'frame_idx': 162,
#      'total_count': 17,
#      'birds_detected': 20,
#      'active_tracks': 4},
#     {'frame_idx': 163,
#      'total_count': 18,
#      'birds_detected': 20,
#      'active_tracks': 3},
#     {'frame_idx': 164,
#      'total_count': 18,
#      'birds_detected': 21,
#      'active_tracks': 3},
#     {'frame_idx': 165,
#      'total_count': 18,
#      'birds_detected': 23,
#      'active_tracks': 5},
#     {'frame_idx': 166,
#      'total_count': 18,
#      'birds_detected': 21,
#      'active_tracks': 2},
#     {'frame_idx': 167,
#      'total_count': 19,
#      'birds_detected': 21,
#      'active_tracks': 2},
#     {'frame_idx': 168,
#      'total_count': 19,
#      'birds_detected': 20,
#      'active_tracks': 1},
#     {'frame_idx': 169,
#      'total_count': 19,
#      'birds_detected': 17,
#      'active_tracks': 3},
#     {'frame_idx': 170,
#      'total_count': 19,
#      'birds_detected': 20,
#      'active_tracks': 3},
#     {'frame_idx': 171,
#      'total_count': 20,
#      'birds_detected': 17,
#      'active_tracks': 3},
#     {'frame_idx': 172,
#      'total_count': 20,
#      'birds_detected': 17,
#      'active_tracks': 4},
#     {'frame_idx': 173,
#      'total_count': 20,
#      'birds_detected': 17,
#      'active_tracks': 4},
#     {'frame_idx': 174,
#      'total_count': 20,
#      'birds_detected': 23,
#      'active_tracks': 6},
#     {'frame_idx': 175,
#      'total_count': 21,
#      'birds_detected': 20,
#      'active_tracks': 4},
#     {'frame_idx': 176,
#      'total_count': 23,
#      'birds_detected': 21,
#      'active_tracks': 6},
#     {'frame_idx': 177,
#      'total_count': 24,
#      'birds_detected': 22,
#      'active_tracks': 4},
#     {'frame_idx': 178,
#      'total_count': 25,
#      'birds_detected': 21,
#      'active_tracks': 4},
#     {'frame_idx': 179,
#      'total_count': 25,
#      'birds_detected': 21,
#      'active_tracks': 4},
#     {'frame_idx': 180,
#      'total_count': 25,
#      'birds_detected': 21,
#      'active_tracks': 5},
#     {'frame_idx': 181,
#      'total_count': 25,
#      'birds_detected': 23,
#      'active_tracks': 4},
#     {'frame_idx': 182,
#      'total_count': 26,
#      'birds_detected': 24,
#      'active_tracks': 4},
#     {'frame_idx': 183,
#      'total_count': 26,
#      'birds_detected': 22,
#      'active_tracks': 5},
#     {'frame_idx': 184,
#      'total_count': 26,
#      'birds_detected': 20,
#      'active_tracks': 4},
#     {'frame_idx': 185,
#      'total_count': 27,
#      'birds_detected': 20,
#      'active_tracks': 4},
#     {'frame_idx': 186,
#      'total_count': 28,
#      'birds_detected': 16,
#      'active_tracks': 2},
#     {'frame_idx': 187,
#      'total_count': 28,
#      'birds_detected': 17,
#      'active_tracks': 2},
#     {'frame_idx': 188,
#      'total_count': 28,
#      'birds_detected': 17,
#      'active_tracks': 1},
#     {'frame_idx': 189,
#      'total_count': 28,
#      'birds_detected': 16,
#      'active_tracks': 1},
#     {'frame_idx': 190,
#      'total_count': 28,
#      'birds_detected': 14,
#      'active_tracks': 2},
#     {'frame_idx': 191,
#      'total_count': 28,
#      'birds_detected': 14,
#      'active_tracks': 2},
#     {'frame_idx': 192,
#      'total_count': 30,
#      'birds_detected': 15,
#      'active_tracks': 2},
#     {'frame_idx': 193,
#      'total_count': 30,
#      'birds_detected': 15,
#      'active_tracks': 1},
#     {'frame_idx': 194,
#      'total_count': 30,
#      'birds_detected': 19,
#      'active_tracks': 1},
#     {'frame_idx': 195,
#      'total_count': 30,
#      'birds_detected': 14,
#      'active_tracks': 0},
#     {'frame_idx': 196,
#      'total_count': 30,
#      'birds_detected': 17,
#      'active_tracks': 3},
#     {'frame_idx': 197,
#      'total_count': 30,
#      'birds_detected': 17,
#      'active_tracks': 3},
#     {'frame_idx': 198,
#      'total_count': 32,
#      'birds_detected': 17,
#      'active_tracks': 2},
#     {'frame_idx': 199,
#      'total_count': 32,
#      'birds_detected': 14,
#      'active_tracks': 3},
#     {'frame_idx': 200,
#      'total_count': 32,
#      'birds_detected': 12,
#      'active_tracks': 2},
#     {'frame_idx': 201,
#      'total_count': 32,
#      'birds_detected': 13,
#      'active_tracks': 2},
#     {'frame_idx': 202,
#      'total_count': 32,
#      'birds_detected': 13,
#      'active_tracks': 2},
#     {'frame_idx': 203,
#      'total_count': 33,
#      'birds_detected': 13,
#      'active_tracks': 2},
#     {'frame_idx': 204,
#      'total_count': 33,
#      'birds_detected': 10,
#      'active_tracks': 2},
#     {'frame_idx': 205,
#      'total_count': 33,
#      'birds_detected': 12,
#      'active_tracks': 3},
#     {'frame_idx': 206,
#      'total_count': 33,
#      'birds_detected': 11,
#      'active_tracks': 3},
#     {'frame_idx': 207,
#      'total_count': 34,
#      'birds_detected': 8,
#      'active_tracks': 2},
#     {'frame_idx': 208,
#      'total_count': 34,
#      'birds_detected': 10,
#      'active_tracks': 1},
#     {'frame_idx': 209,
#      'total_count': 34,
#      'birds_detected': 10,
#      'active_tracks': 1},
#     {'frame_idx': 210,
#      'total_count': 34,
#      'birds_detected': 6,
#      'active_tracks': 0},
#     {'frame_idx': 211,
#      'total_count': 34,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 212,
#      'total_count': 34,
#      'birds_detected': 9,
#      'active_tracks': 2},
#     {'frame_idx': 213,
#      'total_count': 35,
#      'birds_detected': 7,
#      'active_tracks': 3},
#     {'frame_idx': 214,
#      'total_count': 36,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 215,
#      'total_count': 36,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 216,
#      'total_count': 36,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 217,
#      'total_count': 36,
#      'birds_detected': 6,
#      'active_tracks': 1},
#     {'frame_idx': 218,
#      'total_count': 36,
#      'birds_detected': 4,
#      'active_tracks': 1},
#     {'frame_idx': 219,
#      'total_count': 36,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 220,
#      'total_count': 37,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 221,
#      'total_count': 37,
#      'birds_detected': 5,
#      'active_tracks': 1},
#     {'frame_idx': 222,
#      'total_count': 37,
#      'birds_detected': 3,
#      'active_tracks': 1},
#     {'frame_idx': 223,
#      'total_count': 37,
#      'birds_detected': 5,
#      'active_tracks': 2},
#     {'frame_idx': 224,
#      'total_count': 37,
#      'birds_detected': 3,
#      'active_tracks': 2},
#     {'frame_idx': 225,
#      'total_count': 38,
#      'birds_detected': 3,
#      'active_tracks': 2},
#     {'frame_idx': 226,
#      'total_count': 39,
#      'birds_detected': 2,
#      'active_tracks': 1},
#     {'frame_idx': 227,
#      'total_count': 39,
#      'birds_detected': 2,
#      'active_tracks': 1},
#     {'frame_idx': 228,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 229,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 230,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 231,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 232,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 233,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 234,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 235,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 236,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 237,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 238,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 239,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 240,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 241,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 242,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 243,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 244,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 245,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 246,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 247,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 248,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 249,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 250,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 251,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 252,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 253,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 254,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 255,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 256,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 257,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 258,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 259,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 260,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 261,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 262,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0},
#     {'frame_idx': 263,
#      'total_count': 39,
#      'birds_detected': 0,
#      'active_tracks': 0}],
#    'roi_polygon': [[580, 550], [780, 550], [780, 720], [580, 720]]},
#   'success': True}]
